# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Carregar bibliotecas

# %%
import pandas as pd
from datetime import datetime
import random
import sklearn
from sklearn import tree, neighbors, ensemble, discriminant_analysis, neural_network
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.decomposition import PCA, NMF, FastICA
import joblib
from sklearn.pipeline import Pipeline
import pytz

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carregar dados

# %%
dados = pd.read_csv('dados/train_tratado-3_2.csv', sep=';')

dados.head()
# Out:
#                                NU_INSCRICAO  ...  NU_NOTA_MT
# 0  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad  ...       399.4
# 1  2c3acac4b33ec2b195d77e7c04a2d75727fad723  ...       459.8
# 2  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568  ...         0.0
# 3  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe  ...         0.0
# 4  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268  ...         0.0
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Separar dados em atributos (X) e classe (y)

# %%
# Remover identificador do candidato
dados.drop(columns=['NU_INSCRICAO'], inplace=True)
#dados.head()

# %%
X = dados.drop(columns=['NU_NOTA_MT'])
y = dados['NU_NOTA_MT']

# %% [markdown]
# ### Lista com todas as técnicas que serão utilizadas

# %%
tecnicas_regressao = [
    ('RandomForestRegressor', sklearn.ensemble.RandomForestRegressor()),
    ('ExtraTreesRegressor', sklearn.ensemble.ExtraTreesRegressor()),
    ('BaggingRegressor', sklearn.ensemble.BaggingRegressor()),
    ('GradientBoostingRegressor', sklearn.ensemble.GradientBoostingRegressor()),
    ('AdaBoostRegressor', sklearn.ensemble.AdaBoostRegressor()),
    ('HuberRegressor', sklearn.linear_model.HuberRegressor()),
    ('LinearRegression', sklearn.linear_model.LinearRegression()),
    ('PassiveAggressiveRegressor', sklearn.linear_model.PassiveAggressiveRegressor()),
    ('SGDRegressor', sklearn.linear_model.SGDRegressor()),
    ('TheilSenRegressor', sklearn.linear_model.TheilSenRegressor()),
    ('KNeighborsRegressor', sklearn.neighbors.KNeighborsRegressor()),
    ('RadiusNeighborsRegressor', sklearn.neighbors.RadiusNeighborsRegressor()),
    ('MLPRegressor', sklearn.neural_network.MLPRegressor()),
    ('DecisionTreeRegressor', sklearn.tree.DecisionTreeRegressor()),
    ('ExtraTreeRegressor', sklearn.tree.ExtraTreeRegressor())
]

len(tecnicas_regressao)
# Out:
# 15

# %%
def log(mensagem):
    """
    Função para receber uma mensagem e exibir.
    Futuramente esta função pode receber a funcionalidade de salvar as mensagens de log em arquivo
    """
    print(str(datetime.now(pytz.timezone('America/Sao_Paulo'))) + ': ' + mensagem)

# %%
def getNumeroAleatorio(tipo, maximo=None):
    """
    Função para retornar um número aleatório de acordo com o tipo que é passado por parâmetro.        
    """
    
    if tipo == 'cross_validation': 
        return random.randint(3,10) # Definido que a quantidade de divisão dos dados (split) será entre 3 a 10 partes (folds)
    elif tipo == 'random_state':
        return random.randint(1, 42) # Valor do random state poderá variar entre 1 e 42
    elif tipo == 'simples':  # Retorna um número entre 0 e o valor passado por parâmetro
        return random.randint(0,maximo)

# %%
def splitDados(X, y):
    """
    Função para separar os dados de treino e teste, escolhendo aleatoriamente qual será a forma de separar os dados.
    Formas disponíveis de separação:
        - 80% para treino e 20% para teste
        - 75% para treino e 25% para teste
        - 70% para treino e 30% para teste
    """
    
    aleatorio = getNumeroAleatorio('simples', 2)
    
    random_state = getNumeroAleatorio('random_state')
    
    if aleatorio == 0:
        tipo_split = 'train_test_split 20%'
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)
    elif aleatorio == 1:
        tipo_split = 'train_test_split 25%'
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=random_state)
    elif aleatorio == 2:
        tipo_split = 'train_test_split 30%'
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)
    
    return X_train, X_test, y_train, y_test, tipo_split, random_state

# %%
def getNormalizador():
    """
    Retorna aleatoriamente qual normalizador será utilizado ou se não será utilizado normalizador.
    Se algum normalizador for escolhido, é retornado a lista de parâmetros do normalizador escolhido.
    Normalizadores disponíveis:
        - StandardScaler
        - RobustScaler
        - MinMaxScaler
        - Normalizer
    """
    
    normalizador = [(),
                    ('standard_scaler', StandardScaler()),
                    ('robust_scaler', RobustScaler()),
                    ('min_max_scaler', MinMaxScaler()),
                    ('normalizer', Normalizer())
                   ]
    
    aleatorio = getNumeroAleatorio('simples', len(normalizador)-1)
    
    if aleatorio == 0:
        parametros = {}
    elif normalizador[aleatorio][0] == 'standard_scaler':
        parametros = {
            'standard_scaler__with_mean': [True, False],
            'standard_scaler__with_std': [True, False]
        }
    elif normalizador[aleatorio][0] == 'robust_scaler':
        parametros = {
            'robust_scaler__with_centering': [True, False],
            'robust_scaler__with_scaling': [True, False]
        }
    elif normalizador[aleatorio][0] == 'min_max_scaler':
        parametros = {
            'min_max_scaler__feature_range': [(0,1), (1,10), (1,100)]
        }
    elif normalizador[aleatorio][0] == 'normalizer':
        parametros = {
            'normalizer__norm': ('l1', 'l2', 'max')
        }
        
    
    return normalizador[aleatorio], parametros

# %%
def getRedutorDimensionalidade():
    """
    Retorna aleatoriamente qual redutor de dimensionalidade será utilizado ou se não será utilizado redutor de dimensionalidade.
    Se for escolhido um redutor de dimensionalidade, é retornado a lista de parâmetros do redutor de dimensionalidade escolhido.
    Redutor de dimensionalidade disponível:
        - PCA
        - NMF
        - FastICA
    """    
    
    redutor_dimensionalidade = [(),
                                ('pca', PCA()),
                                ('nmf', NMF()),
                                ('FastICA', FastICA())
                                ]
    
    aleatorio = getNumeroAleatorio('simples', len(redutor_dimensionalidade)-1)
    
    if aleatorio == 0:
        parametros = {}
    elif redutor_dimensionalidade[aleatorio][0] == 'pca':
        parametros = {
            'pca__n_components': [None, 3, 5, 7, 9, 11, 13],
            'pca__whiten': [True, False],
            'pca__svd_solver': ('auto', 'full', 'randomized')
        }
    elif redutor_dimensionalidade[aleatorio][0] == 'nmf':
        parametros = {
            'nmf__n_components': [None, 3, 5, 7, 9, 11, 13],
            'nmf__init': ('random', 'nndsvd', 'nndsvda', 'nndsvdar'),
            'nmf__solver': ('cd', 'mu')
        }
    elif redutor_dimensionalidade[aleatorio][0] == 'FastICA':
        parametros = {
            'FastICA__n_components': [None, 3, 5, 7, 9, 11, 13],
            'FastICA__algorithm': ('parallel', 'deflation'),
            'FastICA__whiten': [True, False]
        }
        
    
    return redutor_dimensionalidade[aleatorio], parametros

# %%
def getParametrosTecnica(tecnica):
    """
    Recebe o nome de uma técnica de predição por parâmetro, e retorna os parâmetros da técnica
    """
    
    if  tecnica == 'LinearRegression':
        parametros = {
            'LinearRegression__fit_intercept': [True, False],
            'LinearRegression__normalize': [True, False]
        }
    elif tecnica == 'RandomForestRegressor':
        parametros = {
            'RandomForestRegressor__n_estimators': [5, 10, 15],
            'RandomForestRegressor__criterion': ('mse', 'mae'),
            'RandomForestRegressor__max_features': ('auto', 'sqrt', 'log2'),
            'RandomForestRegressor__bootstrap': [True, False],
            'RandomForestRegressor__warm_start': [True, False]
        }
    elif tecnica == 'ExtraTreesRegressor':
        parametros = {
            'ExtraTreesRegressor__n_estimators': [5, 10, 15],
            'ExtraTreesRegressor__criterion': ('mse', 'mae'),
            'ExtraTreesRegressor__max_features': ('auto', 'sqrt', 'log2'),
            'ExtraTreesRegressor__bootstrap': [True, False],
            'ExtraTreesRegressor__warm_start': [True, False]
        }
    elif tecnica == 'BaggingRegressor':
        parametros = {
            'BaggingRegressor__n_estimators': [5, 10, 15],
            'BaggingRegressor__bootstrap': [True, False],
            'BaggingRegressor__warm_start': [True, False]
        }
    elif tecnica == 'GradientBoostingRegressor':
        parametros = {
            'GradientBoostingRegressor__loss': ('ls', 'lad', 'huber', 'quantile'),
            'GradientBoostingRegressor__criterion': ('friedman_mse', 'mse', 'mae'),
            'GradientBoostingRegressor__max_features': ('auto', 'sqrt', 'log2'),
            'GradientBoostingRegressor__n_estimators': [50, 100, 150],
            'GradientBoostingRegressor__warm_start': [True, False]
        }
    elif tecnica == 'AdaBoostRegressor':
        parametros = {
            'AdaBoostRegressor__loss': ('linear', 'square', 'exponential'),
            'AdaBoostRegressor__n_estimators': [25, 50, 75]
        }
    elif tecnica == 'HuberRegressor':
        parametros = {
            'HuberRegressor__max_iter': [50, 100, 150],
            'HuberRegressor__warm_start': [True, False]
        }
    elif tecnica == 'PassiveAggressiveRegressor':
        parametros = {
            'PassiveAggressiveRegressor__max_iter': [500, 1000, 1500],
            'PassiveAggressiveRegressor__fit_intercept': [True, False],
            'PassiveAggressiveRegressor__early_stopping': [True, False],
            'PassiveAggressiveRegressor__shuffle': [True, False],
            'PassiveAggressiveRegressor__warm_start': [True, False]
        }
    elif tecnica == 'SGDRegressor':
        parametros = {
            'SGDRegressor__loss': ('squared_loss', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'),
            'SGDRegressor__penalty': ('l1', 'l2', 'elasticnet', None),
            'SGDRegressor__max_iter': [500, 1000, 1500],
            'SGDRegressor__shuffle': [True, False],
            'SGDRegressor__warm_start': [True, False],
            'SGDRegressor__learning_rate': ('constant', 'optimal', 'invscaling', 'adaptive'),
            'SGDRegressor__early_stopping': [True, False]
        }
    elif tecnica == 'TheilSenRegressor':
        parametros = {
            'TheilSenRegressor__fit_intercept': [True, False],
            'TheilSenRegressor__max_iter': [150, 300, 450]
        }
    elif tecnica == 'KNeighborsRegressor':
        parametros = {
            'KNeighborsRegressor__n_neighbors': [3,5,7,9],
            'KNeighborsRegressor__weights': ('uniform', 'distance'),
            'KNeighborsRegressor__algorithm': ('auto', 'ball_tree', 'kd_tree', 'brute'),
            'KNeighborsRegressor__p': [1,2]
        }
    elif tecnica == 'RadiusNeighborsRegressor':
        parametros = {
            'RadiusNeighborsRegressor__weights': ('uniform', 'distance'),
            'RadiusNeighborsRegressor__algorithm': ('ball_tree', 'kd_tree', 'brute', 'auto'),
            'RadiusNeighborsRegressor__p': [1, 2]
        }
    elif tecnica == 'MLPRegressor':
        parametros = {
            'MLPRegressor__hidden_layer_sizes': [(1,), (100,), (500,), (1,3), (100,3), (500,3)],
            'MLPRegressor__activation': ('identity', 'logistic', 'tanh', 'relu'),
            'MLPRegressor__solver': ('lbfgs', 'sgd', 'adam'),
            'MLPRegressor__learning_rate': ('constant', 'invscaling', 'adaptive'),
            'MLPRegressor__shuffle': [True, False],
            'MLPRegressor__max_iter': [100, 200, 300, 1000],
            'MLPRegressor__tol': [0.001, 0.0001, 0.00001]
        }
    elif tecnica == 'DecisionTreeRegressor':
        parametros = {
            'DecisionTreeRegressor__criterion': ('gini', 'entropy'),
            'DecisionTreeRegressor__splitter': ('best', 'random'),
            'DecisionTreeRegressor__max_features': ('auto', 'sqrt', 'log2'),
        }
    elif tecnica == 'ExtraTreeRegressor':
        parametros = {
            'ExtraTreeRegressor__criterion': ('mse', 'mae'),
            'ExtraTreeRegressor__max_features': ('auto', 'sqrt', 'log2')
        }
    return parametros

# %%
def salvarDesempenho(resultados):
    """
    Função que recebe um Pandas DataFrame por parâmetro, e salva os dados no arquivo CSV.
    Caso já exista um arquivo, os dados recebidos por parâmetro são adicionados no arquivo
    """
    
    nome_arquivo = 'drive/My Drive/Estudos/codenation/resultados_treino.csv'    
    
    try:
        csv_resultados = pd.read_csv(nome_arquivo, sep=';') # Abrir arquivo existente
        csv_resultados = pd.concat([csv_resultados, resultados]) # Adicionar dados recebidos por parâmetro ao conjunto de dados já existente
        csv_resultados.to_csv(nome_arquivo, sep=';', index=False) # Salvar os dados 
    except FileNotFoundError: # Caso não exista o arquivo, será criado um novo com os dados recebido por parâmetro
        resultados.to_csv(nome_arquivo, sep=';', index=False)

# %%
def avaliarDesempenho(tecnica, y_true, y_pred):
    """
    Função que recebe o valor verdadeiro/real (y_true) e o valor predito (y_pred), 
    aplica os avaliadores de desempenho e retorna o resultado dos avaliadores de desempenho.
    Avaliadores de desempenho aplicados:
        - mean_absolute_error
        - mean_squared_error
        - mean_squared_log_error
        - median_absolute_error
    """
    
    resultados = {}
    resultados['tecnica'] = [tecnica]
    # Aplicando avaliadores de desempenho        
    resultados['mean_absolute_error'] = [sklearn.metrics.mean_absolute_error(y_true, y_pred)]
    resultados['mean_squared_error'] = [sklearn.metrics.mean_squared_error(y_true, y_pred)]
    resultados['mean_squared_log_error'] = [sklearn.metrics.mean_squared_log_error(y_true, y_pred)]
    resultados['median_absolute_error'] = [sklearn.metrics.median_absolute_error(y_true, y_pred)]
        
    log('Técnica: {0} - mean_absolute_error: {1}, mean_squared_error: {2}, mean_squared_log_error: {3}, median_absolute_error: {4}'.format(
            tecnica, resultados['mean_absolute_error'], resultados['mean_squared_error'], resultados['mean_squared_log_error'], resultados['median_absolute_error']) )
    
    pd_resultados = pd.DataFrame(data=resultados)   
    
    return pd_resultados

# %%
def autoModeling(X, y, quantidade_execucoes):
    """
    Função que executa todas as etapas necessárias para separar os dados em treino e teste, e montar o pipeline de treinamento
    O pipeline é composto de:
        - Normalizador e seus parâmetros, se existente
        - Redutor de dimensionalidade e seus parâmetros, se existente
        - Técnica de predição e seus parâmetros
    Após o pipeline estar montado, é realizado uma busca aleatória (Random Search) para encontrar a melhor combinação de parâmetros, essa busca aleatória é executada por 4 vezes
    Após feito a busca aleatória pela melhor combinação de parâmetros, é realizado a predição do 'X_test', para posteriormente aplicar a avaliação de desempenho do modelo de predição
    Aplicado a avaliação de desempenho, seus resultados são salvos em um arquivo .csv
    Posteriomente, o modelo gerado é salvo (.pkl)
    """

    for i in range(1,quantidade_execucoes+1):
    
        log('========== Iniciando execução número: ' + str(i) + ' de ' + str(quantidade_execucoes))

        X_train, X_test, y_train, y_test, tipo_split, random_state_split = splitDados(X, y) # Separando os dados em treino e teste


        pipeline = []
        parametros = {}

        normalizador_pipeline, normalizador_parametros = getNormalizador() # Coletando o normalizador, que será definido aleatoriamente
        normalizador_nome = 'Não utilizado'
        if len(normalizador_pipeline) > 0: # Se for definido que terá normalizador, o normalizador é adicionado no pipeline e no array que salva os parâmetros
            pipeline += [normalizador_pipeline]
            parametros.update(normalizador_parametros)
            normalizador_nome = normalizador_pipeline[0]

        redutor_dimensionalidade_pipeline, redutor_dimensionalidade_parametros = getRedutorDimensionalidade() # Coletando o redutor de dimensionalidade, que será definido aleatoriamente
        redutor_dimensionalidade_nome = 'Não utilizado'
        if len(redutor_dimensionalidade_pipeline) > 0: # Se for definido que terá redutor de dimensionalidade, o redutor de dimensionalidade é adicionado no pipeline e no array que salva os parâmetros
            pipeline += [redutor_dimensionalidade_pipeline]
            parametros.update(redutor_dimensionalidade_parametros)
            redutor_dimensionalidade_nome = redutor_dimensionalidade_pipeline[0]


        log('========== Iniciando treinamento com normalizador: {0}, redutor_dimensionalidade: {1}'.format(normalizador_nome, redutor_dimensionalidade_nome))
        

        for tecnica, model in tecnicas_regressao: # Para cada técnica presente na variável "tecnicas_regressao", coletar os parametros da técnica, realizar o random search e avaliar o seu desempenho
            log('Técnica: ' + tecnica)
            try:

                pipeline_tecnica = pipeline.copy()
                pipeline_tecnica += [(tecnica, model)] # Adicionando a técnica no pipeline

                parametros_tecnica = parametros.copy()
                parametros_tecnica.update(getParametrosTecnica(tecnica)) # Coletando os parâmetros da técnica e adicionando no array de parâmetros

                pipeline_final = Pipeline(pipeline_tecnica)

                cross_validation = getNumeroAleatorio('cross_validation') # Coletando um número aleatório para representar o cross_validation do Random Search
                random_state = getNumeroAleatorio('random_state') # Coletando um número aleatório para representar o random_state do Random Search

                # Executando o Random Search com 4 iterações
                modelo = RandomizedSearchCV(n_iter=4, estimator=pipeline_final, param_distributions=parametros_tecnica, cv=cross_validation, random_state=random_state, n_jobs= -1)
                #modelo = RandomizedSearchCV(n_iter=4, estimator=pipeline_final, param_distributions={}, cv=cross_validation, random_state=random_state, n_jobs= -1)

                modelo.fit(X_train, y_train)

                y_pred = modelo.predict(X_test) # Realizando a predição para os dados de teste
                
                desempenho_tecnica = avaliarDesempenho(tecnica=tecnica, y_true=y_test, y_pred=y_pred) # Chamando a função que avalia o desempenho da técnica

                # Adicionando informações relevantes e informações para identificar como é o modelo gerado, permitindo que seja reproduzido manualmente caso necessário
                identificador_aleatorio = getNumeroAleatorio('simples', 9999999) # Gerar um identificador aleatório para o resultado dessa técnica
                desempenho_tecnica['identificador_aleatorio'] = [identificador_aleatorio]
                desempenho_tecnica['tipo_split'] = [tipo_split]
                desempenho_tecnica['normalizador'] = [normalizador_nome]
                desempenho_tecnica['redutor_dimensionalidade'] = [redutor_dimensionalidade_nome]
                desempenho_tecnica['pipeline'] = [str(pipeline_tecnica)]
                desempenho_tecnica['parametros'] = [str(parametros_tecnica)]
                desempenho_tecnica['random_state_split'] = [random_state_split]
                desempenho_tecnica['random_state_random_search'] = [random_state]
                desempenho_tecnica['cross_validation_random_search'] = [cross_validation]
                desempenho_tecnica['best_estimator'] = [modelo.best_estimator_]
                desempenho_tecnica['best_params'] = [modelo.best_params_]

                salvarDesempenho(desempenho_tecnica) # Salvando o desempenho da técnica



                nome_arquivo = 'modelos/' + str(identificador_aleatorio) + '_' + tecnica + '.pkl' # Criando o nome do arquivo, ex.: 112302_KNeighborsRegressor.pkl
                joblib.dump(modelo.best_estimator_, nome_arquivo) # Salvando o modelo

            except Exception as e:

                log('Erro durante execução da técnica: ' + tecnica)
                #print(e)
                pass # Passar para a próxima técnica



            del(pipeline_tecnica) # Liberar memória
            del(parametros_tecnica) # Liberar memória

        log('========== Finalizado execução número: ' + str(i) + ' de ' + str(quantidade_execucoes))

# %%
# Executando por X vezes o treinamento das técnicas com os dados de treino (X e y) 
autoModeling(X, y, quantidade_execucoes=50)
# Out:
# 2020-05-31 23:40:40.282003-03:00: ========== Iniciando execução número: 1 de 50
# 2020-05-31 23:40:40.286597-03:00: ========== Iniciando treinamento com normalizador: Não utilizado, redutor_dimensionalidade: pca
# 2020-05-31 23:40:40.286698-03:00: Técnica: RandomForestRegressor
# 2020-05-31 23:41:50.715917-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.192311240592375], mean_squared_error: [4792.970416427936], mean_squared_log_error: [0.03729625698720743], median_absolute_error: [33.793333333333294]
# 2020-05-31 23:41:50.864111-03:00: Técnica: ExtraTreesRegressor
# 2020-05-31 23:42:36.556058-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [45.4911022092741], mean_squared_error: [4563.042866051631], mean_squared_log_error: [0.0267490605934823], median_absolute_error: [31.92333333333329]
# 2020-05-31 23:42:36.632076-03:00: Técnica: BaggingRegressor
# 2020-05-31 23:42:49.311917-03:00: Técnica: BaggingRegressor - mean_absolute_error: [46.28419155134741], mean_squared_error: [4690.707759031317], mean_squared_log_error: [0.01879964030663977], median_absolute_error: [31.504999999999967]
# 2020-05-31 23:42:49.369619-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 00:37:56.165319-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 00:37:56.165594-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 00:38:05.129304-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [60.36894916551337], mean_squared_error: [5627.104700833801], mean_squared_log_error: [3.389285139756625], median_absolute_error: [41.01646274963889]
# 2020-06-01 00:38:05.172409-03:00: Técnica: HuberRegressor
# 2020-06-01 00:38:06.437140-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 00:38:06.437770-03:00: Técnica: LinearRegression
# 2020-06-01 00:38:07.182837-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 00:38:07.183428-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 00:38:08.450502-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 00:38:08.451152-03:00: Técnica: SGDRegressor
# 2020-06-01 00:38:11.110041-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 00:38:11.110661-03:00: Técnica: TheilSenRegressor
# 2020-06-01 00:39:09.615738-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 00:39:09.616524-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 00:39:11.529638-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [49.21716223374112], mean_squared_error: [5429.71839559295], mean_squared_log_error: [0.022046463499733045], median_absolute_error: [33.0715081140342]
# 2020-06-01 00:39:11.588017-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 00:39:12.092736-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 00:39:12.092993-03:00: Técnica: MLPRegressor
# 2020-06-01 00:52:14.085353-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 00:52:14.086719-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 00:52:14.495156-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 00:52:14.495393-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 00:52:16.719983-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [63.54686817188639], mean_squared_error: [9060.110782957028], mean_squared_log_error: [0.04980306382546582], median_absolute_error: [42.0]
# 2020-06-01 00:52:16.772019-03:00: ========== Finalizado execução número: 1 de 50
# 2020-06-01 00:52:16.772272-03:00: ========== Iniciando execução número: 2 de 50
# 2020-06-01 00:52:16.779179-03:00: ========== Iniciando treinamento com normalizador: Não utilizado, redutor_dimensionalidade: pca
# 2020-06-01 00:52:16.779368-03:00: Técnica: RandomForestRegressor
# 2020-06-01 00:54:18.945095-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [45.46500825322847], mean_squared_error: [4519.388869780238], mean_squared_log_error: [0.036350416416351734], median_absolute_error: [32.039999999999736]
# 2020-06-01 00:54:19.065145-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 00:55:15.854337-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [46.94126420040781], mean_squared_error: [4727.680225924847], mean_squared_log_error: [0.03684933654934617], median_absolute_error: [33.26999999999998]
# 2020-06-01 00:55:15.952648-03:00: Técnica: BaggingRegressor
# 2020-06-01 00:55:19.280966-03:00: Técnica: BaggingRegressor - mean_absolute_error: [46.34929799009613], mean_squared_error: [4781.590961899214], mean_squared_log_error: [0.019576049753781823], median_absolute_error: [31.06000000000006]
# 2020-06-01 00:55:19.350480-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 00:55:24.939233-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 00:55:24.939457-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 00:55:27.954342-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [77.59071868900283], mean_squared_error: [8391.209986607808], mean_squared_log_error: [4.221424622993811], median_absolute_error: [56.657052896725325]
# 2020-06-01 00:55:28.028521-03:00: Técnica: HuberRegressor
# 2020-06-01 00:55:28.957094-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 00:55:28.957640-03:00: Técnica: LinearRegression
# 2020-06-01 00:55:29.244653-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 00:55:29.245232-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 00:55:29.878985-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 00:55:29.879515-03:00: Técnica: SGDRegressor
# 2020-06-01 00:55:40.861427-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 00:55:40.861625-03:00: Técnica: TheilSenRegressor
# 2020-06-01 00:56:08.076417-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 00:56:08.077076-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 00:56:11.040754-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [45.768022910389746], mean_squared_error: [4571.105543810077], mean_squared_log_error: [0.025913220058502717], median_absolute_error: [32.17038352006904]
# 2020-06-01 00:56:11.097038-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 00:56:11.493962-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 00:56:11.494129-03:00: Técnica: MLPRegressor
# 2020-06-01 00:58:17.135566-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 00:58:17.135837-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 00:58:18.714831-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 00:58:18.715207-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 00:58:23.775025-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [60.573230410719496], mean_squared_error: [8504.223148849404], mean_squared_log_error: [0.04387342565432897], median_absolute_error: [39.30000000000001]
# 2020-06-01 00:58:23.813580-03:00: ========== Finalizado execução número: 2 de 50
# 2020-06-01 00:58:23.813879-03:00: ========== Iniciando execução número: 3 de 50
# 2020-06-01 00:58:23.818566-03:00: ========== Iniciando treinamento com normalizador: normalizer, redutor_dimensionalidade: FastICA
# 2020-06-01 00:58:23.818682-03:00: Técnica: RandomForestRegressor
# 2020-06-01 01:00:57.276472-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [54.539059642308004], mean_squared_error: [6608.104729065845], mean_squared_log_error: [0.0843691843499605], median_absolute_error: [38.09333333333336]
# 2020-06-01 01:00:57.347664-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 01:02:29.295710-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [51.99881848345068], mean_squared_error: [5923.694271533004], mean_squared_log_error: [0.05797425776216492], median_absolute_error: [37.480000000000075]
# 2020-06-01 01:02:29.387009-03:00: Técnica: BaggingRegressor
# 2020-06-01 01:04:16.078958-03:00: Técnica: BaggingRegressor - mean_absolute_error: [52.377839281378975], mean_squared_error: [6052.28917551725], mean_squared_log_error: [0.05719626299148868], median_absolute_error: [35.93333333333334]
# 2020-06-01 01:04:16.164848-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 01:43:13.363344-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 01:43:13.364630-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 01:46:36.576600-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [85.2589831528212], mean_squared_error: [10851.857362697703], mean_squared_log_error: [3.7929305743150565], median_absolute_error: [62.43794520548016]
# 2020-06-01 01:46:36.645868-03:00: Técnica: HuberRegressor
# 2020-06-01 01:48:50.907294-03:00: Técnica: HuberRegressor - mean_absolute_error: [56.0582332794185], mean_squared_error: [7334.875466796459], mean_squared_log_error: [0.4087809994018414], median_absolute_error: [37.40394545659319]
# 2020-06-01 01:48:50.956741-03:00: Técnica: LinearRegression
# 2020-06-01 01:51:40.917477-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 01:51:40.917803-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 01:52:09.380047-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 01:52:09.380699-03:00: Técnica: SGDRegressor
# 2020-06-01 01:52:31.482147-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 01:52:31.482767-03:00: Técnica: TheilSenRegressor
# 2020-06-01 01:53:09.041243-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 01:53:09.042059-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 01:53:54.140690-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [54.68655956119651], mean_squared_error: [6690.230639776471], mean_squared_log_error: [0.052334256408905676], median_absolute_error: [36.47488150923846]
# 2020-06-01 01:53:54.195340-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 01:56:18.446592-03:00: Técnica: RadiusNeighborsRegressor - mean_absolute_error: [56.32083077941731], mean_squared_error: [6835.438644319811], mean_squared_log_error: [0.19456032700446266], median_absolute_error: [42.73904251650913]
# 2020-06-01 01:56:18.491199-03:00: Técnica: MLPRegressor
# 2020-06-01 01:57:54.968776-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 01:57:54.968961-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 01:58:24.273850-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 01:58:24.274292-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 01:59:09.247101-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [72.81257586792911], mean_squared_error: [12315.330298616169], mean_squared_log_error: [0.09070812993861888], median_absolute_error: [45.599999999999966]
# 2020-06-01 01:59:09.285707-03:00: ========== Finalizado execução número: 3 de 50
# 2020-06-01 01:59:09.285974-03:00: ========== Iniciando execução número: 4 de 50
# 2020-06-01 01:59:09.292084-03:00: ========== Iniciando treinamento com normalizador: robust_scaler, redutor_dimensionalidade: FastICA
# 2020-06-01 01:59:09.292199-03:00: Técnica: RandomForestRegressor
# 2020-06-01 02:04:53.466252-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.07336853605244], mean_squared_error: [4733.868004552076], mean_squared_log_error: [0.09175822775133444], median_absolute_error: [34.60499999999996]
# 2020-06-01 02:04:53.544325-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 02:06:32.065802-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [45.59269240106822], mean_squared_error: [4506.053933317148], mean_squared_log_error: [0.039271775325151456], median_absolute_error: [33.69666666666666]
# 2020-06-01 02:06:32.187466-03:00: Técnica: BaggingRegressor
# 2020-06-01 02:07:16.178361-03:00: Técnica: BaggingRegressor - mean_absolute_error: [45.35680990531682], mean_squared_error: [4471.776962782228], mean_squared_log_error: [0.018556195365660926], median_absolute_error: [31.350000000000023]
# 2020-06-01 02:07:16.272148-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 02:20:35.256234-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 02:20:35.256518-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 02:21:23.838766-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [53.12517822319169], mean_squared_error: [5112.059375492967], mean_squared_log_error: [1.366535123562843], median_absolute_error: [42.11623673132459]
# 2020-06-01 02:21:23.884784-03:00: Técnica: HuberRegressor
# 2020-06-01 02:22:14.809507-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 02:22:14.809756-03:00: Técnica: LinearRegression
# 2020-06-01 02:23:19.819344-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 02:23:19.819657-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 02:25:16.862197-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [48.8657455755851], mean_squared_error: [5001.721702091838], mean_squared_log_error: [0.6641878438423224], median_absolute_error: [35.30100626336673]
# 2020-06-01 02:25:16.913221-03:00: Técnica: SGDRegressor
# 2020-06-01 02:27:54.064129-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 02:27:54.064732-03:00: Técnica: TheilSenRegressor
# 2020-06-01 02:29:59.390183-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 02:29:59.391003-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 02:30:04.475190-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [44.22441480419965], mean_squared_error: [4336.690379502977], mean_squared_log_error: [0.028458363195576278], median_absolute_error: [31.04238861295852]
# 2020-06-01 02:30:04.524865-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 02:30:24.063134-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 02:30:24.063297-03:00: Técnica: MLPRegressor
# 2020-06-01 02:47:54.421153-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 02:47:54.423203-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 02:49:36.481600-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 02:49:36.481996-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 02:55:04.219804-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [64.52337946103424], mean_squared_error: [9924.822090313182], mean_squared_log_error: [0.2819046998038385], median_absolute_error: [43.599999999999994]
# 2020-06-01 02:55:04.281040-03:00: ========== Finalizado execução número: 4 de 50
# 2020-06-01 02:55:04.281229-03:00: ========== Iniciando execução número: 5 de 50
# 2020-06-01 02:55:04.289458-03:00: ========== Iniciando treinamento com normalizador: robust_scaler, redutor_dimensionalidade: nmf
# 2020-06-01 02:55:04.289795-03:00: Técnica: RandomForestRegressor
# 2020-06-01 02:55:04.524727-03:00: Erro durante execução da técnica: RandomForestRegressor
# 2020-06-01 02:55:04.524968-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 02:55:07.069203-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [48.38310269482884], mean_squared_error: [5039.092773197378], mean_squared_log_error: [0.032598373935420186], median_absolute_error: [34.5033333333333]
# 2020-06-01 02:55:07.162731-03:00: Técnica: BaggingRegressor
# 2020-06-01 02:55:30.134303-03:00: Técnica: BaggingRegressor - mean_absolute_error: [60.18712308812818], mean_squared_error: [8062.530266634297], mean_squared_log_error: [0.032327595076220836], median_absolute_error: [40.073333333333295]
# 2020-06-01 02:55:30.280485-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 02:55:36.420257-03:00: Técnica: GradientBoostingRegressor - mean_absolute_error: [83.65027131656588], mean_squared_error: [13003.346479815555], mean_squared_log_error: [0.4657784577970006], median_absolute_error: [74.4254815084906]
# 2020-06-01 02:55:36.499193-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 02:55:55.820417-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [57.43717756503833], mean_squared_error: [5666.894321646351], mean_squared_log_error: [2.250709442410732], median_absolute_error: [41.96673623116146]
# 2020-06-01 02:55:55.871327-03:00: Técnica: HuberRegressor
# 2020-06-01 02:55:56.023155-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 02:55:56.023897-03:00: Técnica: LinearRegression
# 2020-06-01 02:55:56.986214-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 02:55:56.986857-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 02:55:59.919912-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [49.46757500398054], mean_squared_error: [5363.373861785302], mean_squared_log_error: [0.3961172684494187], median_absolute_error: [34.62342225058143]
# 2020-06-01 02:55:59.994918-03:00: Técnica: SGDRegressor
# 2020-06-01 02:56:00.514169-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 02:56:00.514442-03:00: Técnica: TheilSenRegressor
# 2020-06-01 02:56:41.683049-03:00: Técnica: TheilSenRegressor - mean_absolute_error: [53.02709483673763], mean_squared_error: [7323.768328279139], mean_squared_log_error: [0.5994384043070197], median_absolute_error: [35.42004253036444]
# 2020-06-01 02:56:41.736577-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 02:56:42.027480-03:00: Erro durante execução da técnica: KNeighborsRegressor
# 2020-06-01 02:56:42.027716-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 02:56:44.062565-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 02:56:44.062730-03:00: Técnica: MLPRegressor
# 2020-06-01 02:56:45.738154-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 02:56:45.738499-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 02:56:46.103950-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 02:56:46.104163-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 02:56:54.719856-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [65.82083029861617], mean_squared_error: [10504.917050254915], mean_squared_log_error: [0.31375784884003066], median_absolute_error: [41.75000000000003]
# 2020-06-01 02:56:54.777046-03:00: ========== Finalizado execução número: 5 de 50
# 2020-06-01 02:56:54.777588-03:00: ========== Iniciando execução número: 6 de 50
# 2020-06-01 02:56:54.783420-03:00: ========== Iniciando treinamento com normalizador: Não utilizado, redutor_dimensionalidade: pca
# 2020-06-01 02:56:54.783696-03:00: Técnica: RandomForestRegressor
# 2020-06-01 03:07:55.228923-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [44.632618700844745], mean_squared_error: [4317.04450799754], mean_squared_log_error: [0.06958409233370702], median_absolute_error: [30.980000000000018]
# 2020-06-01 03:07:55.346251-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 03:08:18.926339-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [45.50591610836003], mean_squared_error: [4533.668649504806], mean_squared_log_error: [0.038567688787580975], median_absolute_error: [31.200000000000102]
# 2020-06-01 03:08:19.035784-03:00: Técnica: BaggingRegressor
# 2020-06-01 03:08:34.416624-03:00: Técnica: BaggingRegressor - mean_absolute_error: [45.04764928633848], mean_squared_error: [4413.699933003204], mean_squared_log_error: [0.029008253136787315], median_absolute_error: [32.45999999999992]
# 2020-06-01 03:08:34.504255-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 03:19:34.227438-03:00: Técnica: GradientBoostingRegressor - mean_absolute_error: [44.740314234882774], mean_squared_error: [4110.4607575759355], mean_squared_log_error: [1.163295511854987], median_absolute_error: [29.623819767571263]
# 2020-06-01 03:19:34.278766-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 03:19:41.632503-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [56.1831716089279], mean_squared_error: [5487.933551806248], mean_squared_log_error: [1.9017928225106848], median_absolute_error: [44.05056061667699]
# 2020-06-01 03:19:41.723272-03:00: Técnica: HuberRegressor
# 2020-06-01 03:19:42.668972-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 03:19:42.669257-03:00: Técnica: LinearRegression
# 2020-06-01 03:19:42.960031-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 03:19:42.960725-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 03:19:43.465180-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [132.11098794226262], mean_squared_error: [27932.40856432271], mean_squared_log_error: [8.356860415835527], median_absolute_error: [98.66790139470214]
# 2020-06-01 03:19:43.520474-03:00: Técnica: SGDRegressor
# 2020-06-01 03:19:48.151612-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 03:19:48.152347-03:00: Técnica: TheilSenRegressor
# 2020-06-01 03:20:24.202427-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 03:20:24.202987-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 03:20:26.622998-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [48.04841255124609], mean_squared_error: [5088.587758809973], mean_squared_log_error: [0.03178535046612495], median_absolute_error: [31.87374876611358]
# 2020-06-01 03:20:26.673183-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 03:20:27.235590-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 03:20:27.236253-03:00: Técnica: MLPRegressor
# 2020-06-01 03:22:55.336161-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 03:22:55.336933-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 03:22:55.667878-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 03:22:55.668212-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 03:22:58.718241-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [60.29799009612584], mean_squared_error: [8173.8232100203895], mean_squared_log_error: [0.04416320736072902], median_absolute_error: [39.099999999999966]
# 2020-06-01 03:22:58.774238-03:00: ========== Finalizado execução número: 6 de 50
# 2020-06-01 03:22:58.774567-03:00: ========== Iniciando execução número: 7 de 50
# 2020-06-01 03:22:58.781402-03:00: ========== Iniciando treinamento com normalizador: robust_scaler, redutor_dimensionalidade: pca
# 2020-06-01 03:22:58.781557-03:00: Técnica: RandomForestRegressor
# 2020-06-01 03:25:32.333830-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.482830784170915], mean_squared_error: [4938.036522554019], mean_squared_log_error: [0.06962254017380226], median_absolute_error: [33.760000000000105]
# 2020-06-01 03:25:32.416889-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 03:26:14.430594-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [46.0146419033746], mean_squared_error: [4662.494646103423], mean_squared_log_error: [0.09207426535038489], median_absolute_error: [32.55000000000007]
# 2020-06-01 03:26:14.516572-03:00: Técnica: BaggingRegressor
# 2020-06-01 03:26:14.758947-03:00: Erro durante execução da técnica: BaggingRegressor
# 2020-06-01 03:26:14.759537-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 04:22:45.197239-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 04:22:45.199117-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 04:22:52.776023-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [71.64413803409292], mean_squared_error: [6840.246581623268], mean_squared_log_error: [5.077062588028948], median_absolute_error: [83.55349162011161]
# 2020-06-01 04:22:52.848423-03:00: Técnica: HuberRegressor
# 2020-06-01 04:22:55.119773-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 04:22:55.120443-03:00: Técnica: LinearRegression
# 2020-06-01 04:22:55.568245-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 04:22:55.568559-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 04:22:56.486885-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 04:22:56.487527-03:00: Técnica: SGDRegressor
# 2020-06-01 04:22:57.562626-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 04:22:57.562919-03:00: Técnica: TheilSenRegressor
# 2020-06-01 04:23:29.350013-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 04:23:29.350713-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 04:23:32.474294-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [44.2269493929915], mean_squared_error: [4380.901824190907], mean_squared_log_error: [0.04891893569972215], median_absolute_error: [30.4957113150042]
# 2020-06-01 04:23:32.543408-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 04:23:33.100849-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 04:23:33.101076-03:00: Técnica: MLPRegressor
# 2020-06-01 04:26:13.859159-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 04:26:13.859437-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 04:26:15.480164-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 04:26:15.480499-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 04:26:20.157982-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [60.76552561301287], mean_squared_error: [8169.8441903374605], mean_squared_log_error: [0.042924858989718186], median_absolute_error: [40.19999999999993]
# 2020-06-01 04:26:20.214714-03:00: ========== Finalizado execução número: 7 de 50
# 2020-06-01 04:26:20.215124-03:00: ========== Iniciando execução número: 8 de 50
# 2020-06-01 04:26:20.225319-03:00: ========== Iniciando treinamento com normalizador: standard_scaler, redutor_dimensionalidade: Não utilizado
# 2020-06-01 04:26:20.225579-03:00: Técnica: RandomForestRegressor
# 2020-06-01 04:27:41.767320-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [46.80799708667153], mean_squared_error: [4832.257546176256], mean_squared_log_error: [0.03343669010986864], median_absolute_error: [32.935]
# 2020-06-01 04:27:41.835682-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 04:28:17.318615-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [45.95245205146881], mean_squared_error: [4685.225360152141], mean_squared_log_error: [0.056480867240685885], median_absolute_error: [31.460000000000065]
# 2020-06-01 04:28:17.417505-03:00: Técnica: BaggingRegressor
# 2020-06-01 04:28:33.917880-03:00: Técnica: BaggingRegressor - mean_absolute_error: [45.252505462490895], mean_squared_error: [4554.759637533382], mean_squared_log_error: [0.03242298164719189], median_absolute_error: [31.23333333333329]
# 2020-06-01 04:28:33.999533-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 04:28:53.517947-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 04:28:53.518268-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 04:29:05.594947-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [49.76393080305116], mean_squared_error: [4949.109321710567], mean_squared_log_error: [0.042823668167319064], median_absolute_error: [40.162081475092606]
# 2020-06-01 04:29:05.652374-03:00: Técnica: HuberRegressor
# 2020-06-01 04:29:10.748744-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 04:29:10.749045-03:00: Técnica: LinearRegression
# 2020-06-01 04:29:11.019800-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 04:29:11.020093-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 04:29:11.726411-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 04:29:11.727069-03:00: Técnica: SGDRegressor
# 2020-06-01 04:29:24.056683-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 04:29:24.056979-03:00: Técnica: TheilSenRegressor
# 2020-06-01 04:30:10.895642-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 04:30:10.896041-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 04:30:14.916419-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [47.07825928623452], mean_squared_error: [5032.5453289147845], mean_squared_log_error: [0.04564505447506841], median_absolute_error: [31.01000000000002]
# 2020-06-01 04:30:14.960618-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 04:30:15.781892-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 04:30:15.782102-03:00: Técnica: MLPRegressor
# 2020-06-01 04:31:50.868240-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 04:31:50.868475-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 04:31:52.468473-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 04:31:52.468777-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 04:32:04.278839-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [60.272141296431165], mean_squared_error: [8307.615021849964], mean_squared_log_error: [0.07400923514068883], median_absolute_error: [37.80000000000004]
# 2020-06-01 04:32:04.321302-03:00: ========== Finalizado execução número: 8 de 50
# 2020-06-01 04:32:04.322158-03:00: ========== Iniciando execução número: 9 de 50
# 2020-06-01 04:32:04.326876-03:00: ========== Iniciando treinamento com normalizador: normalizer, redutor_dimensionalidade: Não utilizado
# 2020-06-01 04:32:04.326984-03:00: Técnica: RandomForestRegressor
# 2020-06-01 04:36:34.846021-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [52.71145261794934], mean_squared_error: [6081.238817156267], mean_squared_log_error: [0.023795411578953], median_absolute_error: [37.406666666666695]
# 2020-06-01 04:36:34.940921-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 04:37:05.669142-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [53.21568827385288], mean_squared_error: [6185.063280440236], mean_squared_log_error: [0.04559024842580006], median_absolute_error: [38.27999999999997]
# 2020-06-01 04:37:05.792606-03:00: Técnica: BaggingRegressor
# 2020-06-01 04:37:20.314547-03:00: Técnica: BaggingRegressor - mean_absolute_error: [52.996291980254114], mean_squared_error: [6202.468574260203], mean_squared_log_error: [0.024082530813200144], median_absolute_error: [36.793333333333294]
# 2020-06-01 04:37:20.406733-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 04:37:42.283105-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 04:37:42.283392-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 04:37:51.101499-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [68.42249175681562], mean_squared_error: [8714.76069677138], mean_squared_log_error: [0.9324849694901752], median_absolute_error: [54.987755102044616]
# 2020-06-01 04:37:51.158032-03:00: Técnica: HuberRegressor
# 2020-06-01 04:37:56.477855-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 04:37:56.478556-03:00: Técnica: LinearRegression
# 2020-06-01 04:37:56.821101-03:00: Técnica: LinearRegression - mean_absolute_error: [60.71033614336519], mean_squared_error: [7851.152529871734], mean_squared_log_error: [0.36497123332143944], median_absolute_error: [47.44595661393981]
# 2020-06-01 04:37:56.869574-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 04:37:57.626218-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 04:37:57.626791-03:00: Técnica: SGDRegressor
# 2020-06-01 04:38:04.122246-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 04:38:04.122893-03:00: Técnica: TheilSenRegressor
# 2020-06-01 04:38:57.134544-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 04:38:57.135441-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 04:39:02.325556-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [56.64933250462909], mean_squared_error: [6984.500919628805], mean_squared_log_error: [0.05109534150592129], median_absolute_error: [41.05159276970437]
# 2020-06-01 04:39:02.378932-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 04:39:13.486021-03:00: Técnica: RadiusNeighborsRegressor - mean_absolute_error: [59.24444745017467], mean_squared_error: [7629.978332945521], mean_squared_log_error: [0.16491986400236067], median_absolute_error: [45.167683857027725]
# 2020-06-01 04:39:13.528581-03:00: Técnica: MLPRegressor
# 2020-06-01 04:39:59.013275-03:00: Técnica: MLPRegressor - mean_absolute_error: [59.24747994753368], mean_squared_error: [7698.657758086221], mean_squared_log_error: [0.0446966062896936], median_absolute_error: [45.158877676557836]
# 2020-06-01 04:39:59.077838-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 04:39:59.521023-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 04:39:59.521406-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 04:40:00.773440-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [67.61221170186937], mean_squared_error: [10427.473296916729], mean_squared_log_error: [0.04919209479073797], median_absolute_error: [43.30000000000001]
# 2020-06-01 04:40:00.816587-03:00: ========== Finalizado execução número: 9 de 50
# 2020-06-01 04:40:00.817684-03:00: ========== Iniciando execução número: 10 de 50
# 2020-06-01 04:40:00.822493-03:00: ========== Iniciando treinamento com normalizador: Não utilizado, redutor_dimensionalidade: pca
# 2020-06-01 04:40:00.822600-03:00: Técnica: RandomForestRegressor
# 2020-06-01 04:41:24.991593-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [45.89570929216429], mean_squared_error: [4551.530603582873], mean_squared_log_error: [0.03329584220691905], median_absolute_error: [32.220000000000084]
# 2020-06-01 04:41:25.087256-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 04:41:59.107954-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [45.387326924944176], mean_squared_error: [4475.322279289251], mean_squared_log_error: [0.03523129982478467], median_absolute_error: [32.80666666666667]
# 2020-06-01 04:41:59.235495-03:00: Técnica: BaggingRegressor
# 2020-06-01 04:42:02.621414-03:00: Técnica: BaggingRegressor - mean_absolute_error: [45.980528206622004], mean_squared_error: [4678.450657410104], mean_squared_log_error: [0.019066265681738123], median_absolute_error: [31.886666666666542]
# 2020-06-01 04:42:02.722091-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 05:26:25.385442-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 05:26:25.387533-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 05:26:31.671241-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [65.9783055493877], mean_squared_error: [6910.611790020506], mean_squared_log_error: [3.068783525520048], median_absolute_error: [46.444234800836455]
# 2020-06-01 05:26:31.767122-03:00: Técnica: HuberRegressor
# 2020-06-01 05:26:32.946933-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 05:26:32.947475-03:00: Técnica: LinearRegression
# 2020-06-01 05:26:33.569648-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 05:26:33.569995-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 05:26:34.250825-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [50.86424364421407], mean_squared_error: [5413.483577080398], mean_squared_log_error: [0.668140072476965], median_absolute_error: [35.57790899263807]
# 2020-06-01 05:26:34.312196-03:00: Técnica: SGDRegressor
# 2020-06-01 05:26:35.038426-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 05:26:35.038997-03:00: Técnica: TheilSenRegressor
# 2020-06-01 05:26:53.992883-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 05:26:53.993499-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 05:26:57.523543-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [45.20295174288766], mean_squared_error: [4485.138343672345], mean_squared_log_error: [0.027614024732478377], median_absolute_error: [31.777777777777715]
# 2020-06-01 05:26:57.593515-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 05:26:58.128280-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 05:26:58.128445-03:00: Técnica: MLPRegressor
# 2020-06-01 05:27:04.636019-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 05:27:04.636331-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 05:27:05.216364-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 05:27:05.216600-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 05:27:17.004927-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [62.62554616953102], mean_squared_error: [8675.23485289834], mean_squared_log_error: [0.06669835185443039], median_absolute_error: [41.19999999999999]
# 2020-06-01 05:27:17.068953-03:00: ========== Finalizado execução número: 10 de 50
# 2020-06-01 05:27:17.070063-03:00: ========== Iniciando execução número: 11 de 50
# 2020-06-01 05:27:17.077697-03:00: ========== Iniciando treinamento com normalizador: robust_scaler, redutor_dimensionalidade: nmf
# 2020-06-01 05:27:17.077924-03:00: Técnica: RandomForestRegressor
# 2020-06-01 05:27:33.977260-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.230358287212354], mean_squared_error: [4792.957116393177], mean_squared_log_error: [0.029989536066751504], median_absolute_error: [33.833333333333485]
# 2020-06-01 05:27:34.080765-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 05:28:39.918092-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [47.711067093892616], mean_squared_error: [4884.188647926983], mean_squared_log_error: [0.0722352881854372], median_absolute_error: [35.220000000000084]
# 2020-06-01 05:28:40.017061-03:00: Técnica: BaggingRegressor
# 2020-06-01 05:28:44.258493-03:00: Técnica: BaggingRegressor - mean_absolute_error: [49.94781823478007], mean_squared_error: [5415.993920743115], mean_squared_log_error: [0.3704068250551903], median_absolute_error: [37.89333333333337]
# 2020-06-01 05:28:44.364365-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 05:28:57.141302-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 05:28:57.141983-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 05:29:24.045485-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [70.91819228679651], mean_squared_error: [7827.234405962205], mean_squared_log_error: [3.3315359422462847], median_absolute_error: [49.93934883720908]
# 2020-06-01 05:29:24.139693-03:00: Técnica: HuberRegressor
# 2020-06-01 05:29:31.233108-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 05:29:31.233354-03:00: Técnica: LinearRegression
# 2020-06-01 05:29:34.111680-03:00: Técnica: LinearRegression - mean_absolute_error: [51.1069732098411], mean_squared_error: [5300.294709414324], mean_squared_log_error: [0.5652351929927346], median_absolute_error: [37.63395542115694]
# 2020-06-01 05:29:34.169914-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 05:29:34.693604-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [52.09117672139067], mean_squared_error: [6295.739465628992], mean_squared_log_error: [1.0968400872429247], median_absolute_error: [35.29301621198522]
# 2020-06-01 05:29:34.749240-03:00: Técnica: SGDRegressor
# 2020-06-01 05:29:35.151910-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 05:29:35.152241-03:00: Técnica: TheilSenRegressor
# 2020-06-01 05:29:47.655032-03:00: Técnica: TheilSenRegressor - mean_absolute_error: [51.59283945025065], mean_squared_error: [6187.202790307255], mean_squared_log_error: [0.6392052883977922], median_absolute_error: [35.10669202769657]
# 2020-06-01 05:29:47.728764-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 05:29:58.295143-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [54.84058646470531], mean_squared_error: [6887.396292196653], mean_squared_log_error: [0.4150783381866645], median_absolute_error: [38.19999999999999]
# 2020-06-01 05:29:58.353343-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 05:29:58.673886-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 05:29:58.674124-03:00: Técnica: MLPRegressor
# 2020-06-01 05:34:15.478003-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 05:34:15.479775-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 05:34:19.071985-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 05:34:19.072747-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 05:34:26.380470-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [64.59507719196039], mean_squared_error: [9284.123376055928], mean_squared_log_error: [0.06856846089026329], median_absolute_error: [43.099999999999966]
# 2020-06-01 05:34:26.450189-03:00: ========== Finalizado execução número: 11 de 50
# 2020-06-01 05:34:26.451098-03:00: ========== Iniciando execução número: 12 de 50
# 2020-06-01 05:34:26.457864-03:00: ========== Iniciando treinamento com normalizador: standard_scaler, redutor_dimensionalidade: FastICA
# 2020-06-01 05:34:26.458075-03:00: Técnica: RandomForestRegressor
# 2020-06-01 05:36:54.969747-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [45.28413632391494], mean_squared_error: [4483.494711745477], mean_squared_log_error: [0.05488627118280966], median_absolute_error: [31.726666666666688]
# 2020-06-01 05:36:55.101435-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 05:37:38.936192-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [47.30535003398388], mean_squared_error: [4996.5516758002395], mean_squared_log_error: [0.03548798358278595], median_absolute_error: [32.54666666666668]
# 2020-06-01 05:37:39.068475-03:00: Técnica: BaggingRegressor
# 2020-06-01 05:38:27.394360-03:00: Técnica: BaggingRegressor - mean_absolute_error: [46.5381881736091], mean_squared_error: [4751.727611327961], mean_squared_log_error: [0.041028687673060074], median_absolute_error: [33.0866666666667]
# 2020-06-01 05:38:27.525311-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 06:11:24.016012-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 06:11:24.016439-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 06:12:32.201920-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [76.48645999713615], mean_squared_error: [7615.686980225521], mean_squared_log_error: [5.50259974910813], median_absolute_error: [84.99623059866973]
# 2020-06-01 06:12:32.292468-03:00: Técnica: HuberRegressor
# 2020-06-01 06:14:38.701195-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 06:14:38.701980-03:00: Técnica: LinearRegression
# 2020-06-01 06:15:45.347899-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 06:15:45.348788-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 06:17:34.751206-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [50.92949735844108], mean_squared_error: [5237.522181080561], mean_squared_log_error: [1.6768466805069433], median_absolute_error: [34.805901598661706]
# 2020-06-01 06:17:34.831510-03:00: Técnica: SGDRegressor
# 2020-06-01 06:18:03.185022-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 06:18:03.185682-03:00: Técnica: TheilSenRegressor
# 2020-06-01 06:19:49.470133-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 06:19:49.471033-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 06:20:30.877476-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [45.83875910282551], mean_squared_error: [4796.118361433149], mean_squared_log_error: [0.03956433788408049], median_absolute_error: [29.579999999999984]
# 2020-06-01 06:20:30.937571-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 06:20:35.802351-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 06:20:35.802993-03:00: Técnica: MLPRegressor
# 2020-06-01 06:34:08.442346-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 06:34:08.443449-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 06:34:43.758867-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 06:34:43.759665-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 06:35:26.858703-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [60.125633556655984], mean_squared_error: [8336.177882318672], mean_squared_log_error: [0.07771494728522538], median_absolute_error: [38.5]
# 2020-06-01 06:35:26.953621-03:00: ========== Finalizado execução número: 12 de 50
# 2020-06-01 06:35:26.953920-03:00: ========== Iniciando execução número: 13 de 50
# 2020-06-01 06:35:26.962106-03:00: ========== Iniciando treinamento com normalizador: standard_scaler, redutor_dimensionalidade: FastICA
# 2020-06-01 06:35:26.962606-03:00: Técnica: RandomForestRegressor
# 2020-06-01 06:36:08.762580-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.156149550861855], mean_squared_error: [4851.231553904669], mean_squared_log_error: [0.04546803005874181], median_absolute_error: [33.26000000000005]
# 2020-06-01 06:36:08.882187-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 06:39:52.718497-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [47.783110787407956], mean_squared_error: [4959.5512219794455], mean_squared_log_error: [0.05152544919388487], median_absolute_error: [34.126666666666665]
# 2020-06-01 06:39:52.866731-03:00: Técnica: BaggingRegressor
# 2020-06-01 06:40:43.777829-03:00: Técnica: BaggingRegressor - mean_absolute_error: [46.824785142024766], mean_squared_error: [4752.692890386016], mean_squared_log_error: [0.03176998089924667], median_absolute_error: [32.900000000000034]
# 2020-06-01 06:40:43.885054-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 07:32:30.779859-03:00: Técnica: GradientBoostingRegressor - mean_absolute_error: [45.40709275198588], mean_squared_error: [4284.364890634113], mean_squared_log_error: [0.7261286845890385], median_absolute_error: [31.99161217909335]
# 2020-06-01 07:32:30.870112-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 07:34:14.408825-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [49.105304155545916], mean_squared_error: [4884.898552900254], mean_squared_log_error: [0.10707668782431991], median_absolute_error: [38.28878842676306]
# 2020-06-01 07:34:14.486645-03:00: Técnica: HuberRegressor
# 2020-06-01 07:34:21.934749-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 07:34:21.935000-03:00: Técnica: LinearRegression
# 2020-06-01 07:35:08.719683-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 07:35:08.720445-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 07:35:40.495062-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [49.84826435597405], mean_squared_error: [5304.036142352486], mean_squared_log_error: [0.5132271845989961], median_absolute_error: [35.90601238123742]
# 2020-06-01 07:35:40.562888-03:00: Técnica: SGDRegressor
# 2020-06-01 07:35:57.892994-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 07:35:57.893631-03:00: Técnica: TheilSenRegressor
# 2020-06-01 07:39:26.217564-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 07:39:26.218122-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 07:42:19.216416-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [50.77087965881179], mean_squared_error: [5765.960964543164], mean_squared_log_error: [0.031197319040631537], median_absolute_error: [35.80845048955166]
# 2020-06-01 07:42:19.271516-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 07:42:20.028041-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 07:42:20.028215-03:00: Técnica: MLPRegressor
# 2020-06-01 07:42:28.561239-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 07:42:28.561858-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 07:44:14.115094-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 07:44:14.116169-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 07:45:07.531213-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [62.047293032289396], mean_squared_error: [8667.124068948773], mean_squared_log_error: [0.04379288344852243], median_absolute_error: [39.599999999999966]
# 2020-06-01 07:45:07.601780-03:00: ========== Finalizado execução número: 13 de 50
# 2020-06-01 07:45:07.602345-03:00: ========== Iniciando execução número: 14 de 50
# 2020-06-01 07:45:07.608803-03:00: ========== Iniciando treinamento com normalizador: min_max_scaler, redutor_dimensionalidade: FastICA
# 2020-06-01 07:45:07.609204-03:00: Técnica: RandomForestRegressor
# 2020-06-01 07:57:09.916909-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.94709881039087], mean_squared_error: [4960.453455628389], mean_squared_log_error: [0.03742884209566189], median_absolute_error: [33.50333333333327]
# 2020-06-01 07:57:10.091386-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 07:59:28.723720-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [48.84961155620296], mean_squared_error: [5132.9847837662865], mean_squared_log_error: [0.04453175947428742], median_absolute_error: [35.363333333333316]
# 2020-06-01 07:59:28.929137-03:00: Técnica: BaggingRegressor
# 2020-06-01 08:01:16.474710-03:00: Técnica: BaggingRegressor - mean_absolute_error: [47.632787084243745], mean_squared_error: [4948.088951379786], mean_squared_log_error: [0.042789827261021623], median_absolute_error: [34.16999999999996]
# 2020-06-01 08:01:16.591318-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 08:41:13.873863-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 08:41:13.875446-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 08:41:42.223011-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [90.12326584221567], mean_squared_error: [10413.176460795374], mean_squared_log_error: [5.873093561473541], median_absolute_error: [103.66712378672673]
# 2020-06-01 08:41:42.316477-03:00: Técnica: HuberRegressor
# 2020-06-01 08:45:09.493168-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 08:45:09.494037-03:00: Técnica: LinearRegression
# 2020-06-01 08:45:45.477954-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 08:45:45.478274-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 08:47:11.418286-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 08:47:11.419055-03:00: Técnica: SGDRegressor
# 2020-06-01 08:48:44.570336-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 08:48:44.570632-03:00: Técnica: TheilSenRegressor
# 2020-06-01 08:53:00.531663-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 08:53:00.532961-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 08:55:10.811271-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [49.123619810633656], mean_squared_error: [5267.445376693372], mean_squared_log_error: [0.03473668127261722], median_absolute_error: [34.900000000000006]
# 2020-06-01 08:55:10.891587-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 08:55:43.068046-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 08:55:43.068302-03:00: Técnica: MLPRegressor
# 2020-06-01 08:57:42.809490-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 08:57:42.810463-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 09:00:49.170651-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 09:00:49.171664-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 09:01:51.505731-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [63.47294246176256], mean_squared_error: [9227.341154406411], mean_squared_log_error: [0.0888818333434709], median_absolute_error: [40.85000000000002]
# 2020-06-01 09:01:51.570834-03:00: ========== Finalizado execução número: 14 de 50
# 2020-06-01 09:01:51.572149-03:00: ========== Iniciando execução número: 15 de 50
# 2020-06-01 09:01:51.583762-03:00: ========== Iniciando treinamento com normalizador: standard_scaler, redutor_dimensionalidade: nmf
# 2020-06-01 09:01:51.583963-03:00: Técnica: RandomForestRegressor
# 2020-06-01 09:03:08.485481-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [59.32050983248361], mean_squared_error: [8236.611998834669], mean_squared_log_error: [0.07178922914091092], median_absolute_error: [37.49000000000001]
# 2020-06-01 09:03:08.561171-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 09:03:54.158497-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [58.98852148579753], mean_squared_error: [8296.383848215586], mean_squared_log_error: [0.22919679378877542], median_absolute_error: [37.84]
# 2020-06-01 09:03:54.266225-03:00: Técnica: BaggingRegressor
# 2020-06-01 09:04:11.742077-03:00: Técnica: BaggingRegressor - mean_absolute_error: [56.905804806991995], mean_squared_error: [8552.979052439912], mean_squared_log_error: [0.7581038531713244], median_absolute_error: [35.359999999999985]
# 2020-06-01 09:04:11.870140-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 09:23:00.626794-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 09:23:00.627467-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 09:23:01.129139-03:00: Erro durante execução da técnica: AdaBoostRegressor
# 2020-06-01 09:23:01.131229-03:00: Técnica: HuberRegressor
# 2020-06-01 09:23:01.872340-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 09:23:01.873351-03:00: Técnica: LinearRegression
# 2020-06-01 09:23:05.213739-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 09:23:05.214553-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 09:23:08.723539-03:00: Técnica: PassiveAggressiveRegressor - mean_absolute_error: [49.345453431724245], mean_squared_error: [5232.155265373132], mean_squared_log_error: [0.5203937496858778], median_absolute_error: [33.92390122545282]
# 2020-06-01 09:23:08.800608-03:00: Técnica: SGDRegressor
# 2020-06-01 09:23:17.128562-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 09:23:17.129246-03:00: Técnica: TheilSenRegressor
# 2020-06-01 09:23:57.950538-03:00: Técnica: TheilSenRegressor - mean_absolute_error: [50.84873692323946], mean_squared_error: [5871.395508900246], mean_squared_log_error: [0.7098045410799855], median_absolute_error: [33.88854077541532]
# 2020-06-01 09:23:58.017344-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 09:23:58.549399-03:00: Erro durante execução da técnica: KNeighborsRegressor
# 2020-06-01 09:23:58.549690-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 09:24:00.054778-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 09:24:00.055046-03:00: Técnica: MLPRegressor
# 2020-06-01 09:24:01.781218-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 09:24:01.781670-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 09:24:02.630383-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 09:24:02.631332-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 09:24:04.568141-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [62.203787327021125], mean_squared_error: [8870.584355426074], mean_squared_log_error: [0.06039060548398782], median_absolute_error: [41.849999999999994]
# 2020-06-01 09:24:04.643256-03:00: ========== Finalizado execução número: 15 de 50
# 2020-06-01 09:24:04.643933-03:00: ========== Iniciando execução número: 16 de 50
# 2020-06-01 09:24:04.651025-03:00: ========== Iniciando treinamento com normalizador: robust_scaler, redutor_dimensionalidade: pca
# 2020-06-01 09:24:04.651495-03:00: Técnica: RandomForestRegressor
# 2020-06-01 09:24:47.682988-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.93731721526362], mean_squared_error: [4976.233836382173], mean_squared_log_error: [0.020206222653068], median_absolute_error: [34.95999999999992]
# 2020-06-01 09:24:47.798151-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 09:26:13.494331-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [47.32521409845616], mean_squared_error: [4906.364298863967], mean_squared_log_error: [0.03570176528844521], median_absolute_error: [32.78000000000003]
# 2020-06-01 09:26:13.627692-03:00: Técnica: BaggingRegressor
# 2020-06-01 09:26:23.951642-03:00: Técnica: BaggingRegressor - mean_absolute_error: [46.35491989513545], mean_squared_error: [4675.939457209437], mean_squared_log_error: [0.019098537516897454], median_absolute_error: [33.41000000000008]
# 2020-06-01 09:26:24.063174-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 10:16:34.919335-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 10:16:34.922550-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 10:16:40.555187-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [70.93714457289927], mean_squared_error: [7359.022368330439], mean_squared_log_error: [3.808024528924811], median_absolute_error: [48.417795224075896]
# 2020-06-01 10:16:40.663791-03:00: Técnica: HuberRegressor
# 2020-06-01 10:16:45.103622-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 10:16:45.104323-03:00: Técnica: LinearRegression
# 2020-06-01 10:16:45.574017-03:00: Técnica: LinearRegression - mean_absolute_error: [55.51296116328295], mean_squared_error: [7141.108578636098], mean_squared_log_error: [1.1772578950102741], median_absolute_error: [36.70909368247004]
# 2020-06-01 10:16:45.679714-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 10:16:46.079886-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 10:16:46.080544-03:00: Técnica: SGDRegressor
# 2020-06-01 10:16:47.098263-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 10:16:47.098511-03:00: Técnica: TheilSenRegressor
# 2020-06-01 10:17:10.233696-03:00: Técnica: TheilSenRegressor - mean_absolute_error: [55.110269941901], mean_squared_error: [6839.499219456515], mean_squared_log_error: [0.5577999416406018], median_absolute_error: [34.71294642841406]
# 2020-06-01 10:17:10.298552-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 10:17:14.167984-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [46.52818858973826], mean_squared_error: [4730.477725021847], mean_squared_log_error: [0.0194604405540706], median_absolute_error: [33.171428571428635]
# 2020-06-01 10:17:14.233288-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 10:17:14.487804-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 10:17:14.489064-03:00: Técnica: MLPRegressor
# 2020-06-01 10:24:46.775627-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 10:24:46.776687-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 10:24:47.567509-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 10:24:47.568337-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 10:24:52.807638-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [63.171162248762016], mean_squared_error: [8855.033987765803], mean_squared_log_error: [0.03572826816883457], median_absolute_error: [41.19999999999999]
# 2020-06-01 10:24:52.896412-03:00: ========== Finalizado execução número: 16 de 50
# 2020-06-01 10:24:52.897208-03:00: ========== Iniciando execução número: 17 de 50
# 2020-06-01 10:24:52.905904-03:00: ========== Iniciando treinamento com normalizador: min_max_scaler, redutor_dimensionalidade: Não utilizado
# 2020-06-01 10:24:52.906347-03:00: Técnica: RandomForestRegressor
# 2020-06-01 10:26:39.641404-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [46.825185724690456], mean_squared_error: [4726.271307825524], mean_squared_log_error: [0.0458377783900404], median_absolute_error: [32.90333333333331]
# 2020-06-01 10:26:39.765370-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 10:27:29.272319-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [48.65889657683905], mean_squared_error: [5161.501780589949], mean_squared_log_error: [0.04236633027456501], median_absolute_error: [33.61500000000001]
# 2020-06-01 10:27:29.390615-03:00: Técnica: BaggingRegressor
# 2020-06-01 10:27:39.349667-03:00: Técnica: BaggingRegressor - mean_absolute_error: [47.12429351784414], mean_squared_error: [4813.432485105608], mean_squared_log_error: [0.019479812695465778], median_absolute_error: [32.629999999999995]
# 2020-06-01 10:27:39.467681-03:00: Técnica: GradientBoostingRegressor
# 2020-06-01 10:46:09.731857-03:00: Erro durante execução da técnica: GradientBoostingRegressor
# 2020-06-01 10:46:09.732571-03:00: Técnica: AdaBoostRegressor
# 2020-06-01 10:46:22.190471-03:00: Técnica: AdaBoostRegressor - mean_absolute_error: [53.519611756724636], mean_squared_error: [5322.5676635891405], mean_squared_log_error: [0.8437528076678825], median_absolute_error: [44.21816463454394]
# 2020-06-01 10:46:22.263634-03:00: Técnica: HuberRegressor
# 2020-06-01 10:46:23.654356-03:00: Erro durante execução da técnica: HuberRegressor
# 2020-06-01 10:46:23.655018-03:00: Técnica: LinearRegression
# 2020-06-01 10:46:24.067268-03:00: Erro durante execução da técnica: LinearRegression
# 2020-06-01 10:46:24.067944-03:00: Técnica: PassiveAggressiveRegressor
# 2020-06-01 10:46:24.667013-03:00: Erro durante execução da técnica: PassiveAggressiveRegressor
# 2020-06-01 10:46:24.667776-03:00: Técnica: SGDRegressor
# 2020-06-01 10:46:26.389680-03:00: Erro durante execução da técnica: SGDRegressor
# 2020-06-01 10:46:26.390318-03:00: Técnica: TheilSenRegressor
# 2020-06-01 10:47:13.971117-03:00: Erro durante execução da técnica: TheilSenRegressor
# 2020-06-01 10:47:13.971904-03:00: Técnica: KNeighborsRegressor
# 2020-06-01 10:47:19.165779-03:00: Técnica: KNeighborsRegressor - mean_absolute_error: [48.40814518086914], mean_squared_error: [5168.381285865861], mean_squared_log_error: [0.060048830136812434], median_absolute_error: [33.97222222222223]
# 2020-06-01 10:47:19.229780-03:00: Técnica: RadiusNeighborsRegressor
# 2020-06-01 10:47:19.841713-03:00: Erro durante execução da técnica: RadiusNeighborsRegressor
# 2020-06-01 10:47:19.841968-03:00: Técnica: MLPRegressor
# 2020-06-01 11:03:41.666999-03:00: Erro durante execução da técnica: MLPRegressor
# 2020-06-01 11:03:41.668490-03:00: Técnica: DecisionTreeRegressor
# 2020-06-01 11:03:42.064648-03:00: Erro durante execução da técnica: DecisionTreeRegressor
# 2020-06-01 11:03:42.065013-03:00: Técnica: ExtraTreeRegressor
# 2020-06-01 11:03:47.073224-03:00: Técnica: ExtraTreeRegressor - mean_absolute_error: [62.44643117261472], mean_squared_error: [8626.189806991988], mean_squared_log_error: [0.04825015433804508], median_absolute_error: [43.75]
# 2020-06-01 11:03:47.136777-03:00: ========== Finalizado execução número: 17 de 50
# 2020-06-01 11:03:47.137986-03:00: ========== Iniciando execução número: 18 de 50
# 2020-06-01 11:03:47.144334-03:00: ========== Iniciando treinamento com normalizador: robust_scaler, redutor_dimensionalidade: FastICA
# 2020-06-01 11:03:47.144498-03:00: Técnica: RandomForestRegressor
# 2020-06-01 11:06:38.602718-03:00: Técnica: RandomForestRegressor - mean_absolute_error: [47.108204661325566], mean_squared_error: [4700.990692461763], mean_squared_log_error: [0.03177214052148423], median_absolute_error: [33.90999999999991]
# 2020-06-01 11:06:38.712013-03:00: Técnica: ExtraTreesRegressor
# 2020-06-01 11:10:48.294555-03:00: Técnica: ExtraTreesRegressor - mean_absolute_error: [47.74781500364166], mean_squared_error: [4807.434707920613], mean_squared_log_error: [0.041258750848537674], median_absolute_error: [34.539999999999964]
# 2020-06-01 11:10:48.378576-03:00: Técnica: BaggingRegressor
# 2020-06-01 11:15:51.891760-03:00: Técnica: BaggingRegressor - mean_absolute_error: [50.07708667152221], mean_squared_error: [5464.428487399854], mean_squared_log_error: [0.11277442659168307], median_absolute_error: [35.53000000000003]
# 2020-06-01 11:15:51.994951-03:00: Técnica: GradientBoostingRegressor

# %% [markdown]
# ****
# # Próxima etapa: "Evaluation"
