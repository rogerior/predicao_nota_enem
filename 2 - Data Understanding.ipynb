# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Carregar bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Selecionar as colunas que estão presentes nos dados de teste

# %%
test = pd.read_csv('dados/test.csv', sep=',', index_col=None)
test.head()
# Out:
#                                NU_INSCRICAO  CO_UF_RESIDENCIA  ... Q027  Q047
# 0  73ff9fcc02f0a99919906c942c2e1a1042cdcf98                41  ...    C     A
# 1  71a95f9f1b91a82c65ad94abbdf9f54e6066f968                21  ...    F     A
# 2  b38a03232f43b11c9d0788abaf060f7366053b6d                23  ...  NaN     A
# 3  70b682d9a3636be23f6120fa9d6b164eb3c6002d                15  ...  NaN     A
# 4  715494628a50142ce8cb17191cfe6d0f3cae0934                41  ...  NaN     A
#
# [5 rows x 47 columns]

# %%
test.shape
# Out:
# (4576, 47)

# %%
test_columns = list(test.columns)
test_columns
# Out:
# ['NU_INSCRICAO',
#  'CO_UF_RESIDENCIA',
#  'SG_UF_RESIDENCIA',
#  'NU_IDADE',
#  'TP_SEXO',
#  'TP_COR_RACA',
#  'TP_NACIONALIDADE',
#  'TP_ST_CONCLUSAO',
#  'TP_ANO_CONCLUIU',
#  'TP_ESCOLA',
#  'TP_ENSINO',
#  'IN_TREINEIRO',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'IN_BAIXA_VISAO',
#  'IN_CEGUEIRA',
#  'IN_SURDEZ',
#  'IN_DISLEXIA',
#  'IN_DISCALCULIA',
#  'IN_SABATISTA',
#  'IN_GESTANTE',
#  'IN_IDOSO',
#  'TP_PRESENCA_CN',
#  'TP_PRESENCA_CH',
#  'TP_PRESENCA_LC',
#  'CO_PROVA_CN',
#  'CO_PROVA_CH',
#  'CO_PROVA_LC',
#  'CO_PROVA_MT',
#  'NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_LC',
#  'TP_LINGUA',
#  'TP_STATUS_REDACAO',
#  'NU_NOTA_COMP1',
#  'NU_NOTA_COMP2',
#  'NU_NOTA_COMP3',
#  'NU_NOTA_COMP4',
#  'NU_NOTA_COMP5',
#  'NU_NOTA_REDACAO',
#  'Q001',
#  'Q002',
#  'Q006',
#  'Q024',
#  'Q025',
#  'Q026',
#  'Q027',
#  'Q047']

# %%
# Adicionando coluna alvo (y)
test_columns.append('NU_NOTA_MT')
test_columns
# Out:
# ['NU_INSCRICAO',
#  'CO_UF_RESIDENCIA',
#  'SG_UF_RESIDENCIA',
#  'NU_IDADE',
#  'TP_SEXO',
#  'TP_COR_RACA',
#  'TP_NACIONALIDADE',
#  'TP_ST_CONCLUSAO',
#  'TP_ANO_CONCLUIU',
#  'TP_ESCOLA',
#  'TP_ENSINO',
#  'IN_TREINEIRO',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'IN_BAIXA_VISAO',
#  'IN_CEGUEIRA',
#  'IN_SURDEZ',
#  'IN_DISLEXIA',
#  'IN_DISCALCULIA',
#  'IN_SABATISTA',
#  'IN_GESTANTE',
#  'IN_IDOSO',
#  'TP_PRESENCA_CN',
#  'TP_PRESENCA_CH',
#  'TP_PRESENCA_LC',
#  'CO_PROVA_CN',
#  'CO_PROVA_CH',
#  'CO_PROVA_LC',
#  'CO_PROVA_MT',
#  'NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_LC',
#  'TP_LINGUA',
#  'TP_STATUS_REDACAO',
#  'NU_NOTA_COMP1',
#  'NU_NOTA_COMP2',
#  'NU_NOTA_COMP3',
#  'NU_NOTA_COMP4',
#  'NU_NOTA_COMP5',
#  'NU_NOTA_REDACAO',
#  'Q001',
#  'Q002',
#  'Q006',
#  'Q024',
#  'Q025',
#  'Q026',
#  'Q027',
#  'Q047',
#  'NU_NOTA_MT']

# %% [markdown]
# ### Carregar dados

# %%
dados = pd.read_csv('dados/train.csv', sep=',', index_col=0)

dados.head(10)
# Out:
#                                 NU_INSCRICAO  NU_ANO  ...  Q049 Q050
# 1   ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016  ...     B    D
# 2   2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016  ...     C    A
# 3   f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016  ...     B    A
# 4   3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016  ...     A    A
# 5   bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016  ...     A    A
# 6   a37c99ec251d4f6e8ddbeabadf1c87fdbfddc4d1    2016  ...     A    A
# 7   63b4e128e9ffe8ab27f5d093db1976ef4f353e0a    2016  ...     A    A
# 8   2eb189d4912f64b19d1967e8e84b6141aba18770    2016  ...     A    A
# 9   5822cb43e0800429be2084b3f86a63aaa73fa66c    2016  ...     B    A
# 10  94f7e277f87cd58e10a45da4ad5dd168651cf3ef    2016  ...     B    C
#
# [10 rows x 166 columns]

# %% [markdown]
# ### Quantidade de linhas e colunas

# %%
dados.shape
# Out:
# (13730, 166)

# %% [markdown]
# ### Selecionar apenas as colunas que estão presentes nos dados de test

# %%
dados = dados[test_columns]
dados.head()
# Out:
#                                NU_INSCRICAO  CO_UF_RESIDENCIA  ... Q047  NU_NOTA_MT
# 1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad                43  ...    A       399.4
# 2  2c3acac4b33ec2b195d77e7c04a2d75727fad723                23  ...    A       459.8
# 3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568                23  ...    A         NaN
# 4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe                33  ...    D         NaN
# 5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268                13  ...    A         NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Quantidade de linhas e colunas

# %%
dados.shape
# Out:
# (13730, 48)

# %% [markdown]
# ### Descrição estatística dos atributos númericos

# %%
dados.describe()
# Out:
#        CO_UF_RESIDENCIA      NU_IDADE  ...  NU_NOTA_REDACAO    NU_NOTA_MT
# count      13730.000000  13730.000000  ...     10133.000000  10133.000000
# mean          30.736708     21.593809  ...       529.048258    482.497928
# std            9.862405      7.043654  ...       154.294758     99.826323
# min           11.000000     13.000000  ...         0.000000      0.000000
# 25%           23.000000     17.000000  ...       440.000000    408.900000
# 50%           31.000000     19.000000  ...       540.000000    461.200000
# 75%           35.000000     23.000000  ...       600.000000    537.600000
# max           53.000000     67.000000  ...      1000.000000    952.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# ### Tipos dos atributos

# %%
dados.dtypes
# Out:
# NU_INSCRICAO               object
# CO_UF_RESIDENCIA            int64
# SG_UF_RESIDENCIA           object
# NU_IDADE                    int64
# TP_SEXO                    object
# TP_COR_RACA                 int64
# TP_NACIONALIDADE            int64
# TP_ST_CONCLUSAO             int64
# TP_ANO_CONCLUIU             int64
# TP_ESCOLA                   int64
# TP_ENSINO                 float64
# IN_TREINEIRO                int64
# TP_DEPENDENCIA_ADM_ESC    float64
# IN_BAIXA_VISAO              int64
# IN_CEGUEIRA                 int64
# IN_SURDEZ                   int64
# IN_DISLEXIA                 int64
# IN_DISCALCULIA              int64
# IN_SABATISTA                int64
# IN_GESTANTE                 int64
# IN_IDOSO                    int64
# TP_PRESENCA_CN              int64
# TP_PRESENCA_CH              int64
# TP_PRESENCA_LC              int64
# CO_PROVA_CN                object
# CO_PROVA_CH                object
# CO_PROVA_LC                object
# ...

# %% [markdown]
# ### Verificar se existe valores nulos nos dados

# %%
train_nulos = dados.isnull().sum().reset_index()
train_nulos
# Out:
#                      index     0
# 0             NU_INSCRICAO     0
# 1         CO_UF_RESIDENCIA     0
# 2         SG_UF_RESIDENCIA     0
# 3                 NU_IDADE     0
# 4                  TP_SEXO     0
# 5              TP_COR_RACA     0
# 6         TP_NACIONALIDADE     0
# 7          TP_ST_CONCLUSAO     0
# 8          TP_ANO_CONCLUIU     0
# 9                TP_ESCOLA     0
# 10               TP_ENSINO  9448
# 11            IN_TREINEIRO     0
# 12  TP_DEPENDENCIA_ADM_ESC  9448
# 13          IN_BAIXA_VISAO     0
# 14             IN_CEGUEIRA     0
# 15               IN_SURDEZ     0
# 16             IN_DISLEXIA     0
# 17          IN_DISCALCULIA     0
# 18            IN_SABATISTA     0
# 19             IN_GESTANTE     0
# 20                IN_IDOSO     0
# 21          TP_PRESENCA_CN     0
# 22          TP_PRESENCA_CH     0
# 23          TP_PRESENCA_LC     0
# 24             CO_PROVA_CN     0
# 25             CO_PROVA_CH     0
# 26             CO_PROVA_LC     0
# ...

# %%
test_nulos = test.isnull().sum().reset_index()
test_nulos
# Out:
#                      index     0
# 0             NU_INSCRICAO     0
# 1         CO_UF_RESIDENCIA     0
# 2         SG_UF_RESIDENCIA     0
# 3                 NU_IDADE     0
# 4                  TP_SEXO     0
# 5              TP_COR_RACA     0
# 6         TP_NACIONALIDADE     0
# 7          TP_ST_CONCLUSAO     0
# 8          TP_ANO_CONCLUIU     0
# 9                TP_ESCOLA     0
# 10               TP_ENSINO  3096
# 11            IN_TREINEIRO     0
# 12  TP_DEPENDENCIA_ADM_ESC  3096
# 13          IN_BAIXA_VISAO     0
# 14             IN_CEGUEIRA     0
# 15               IN_SURDEZ     0
# 16             IN_DISLEXIA     0
# 17          IN_DISCALCULIA     0
# 18            IN_SABATISTA     0
# 19             IN_GESTANTE     0
# 20                IN_IDOSO     0
# 21          TP_PRESENCA_CN     0
# 22          TP_PRESENCA_CH     0
# 23          TP_PRESENCA_LC     0
# 24             CO_PROVA_CN     0
# 25             CO_PROVA_CH     0
# 26             CO_PROVA_LC     0
# ...

# %% [markdown]
# Comparar colunas com valores nulos nos dois datasets

# %%
pd.concat([train_nulos, test_nulos], axis=1)
# Out:
#                      index     0                   index       0
# 0             NU_INSCRICAO     0            NU_INSCRICAO     0.0
# 1         CO_UF_RESIDENCIA     0        CO_UF_RESIDENCIA     0.0
# 2         SG_UF_RESIDENCIA     0        SG_UF_RESIDENCIA     0.0
# 3                 NU_IDADE     0                NU_IDADE     0.0
# 4                  TP_SEXO     0                 TP_SEXO     0.0
# 5              TP_COR_RACA     0             TP_COR_RACA     0.0
# 6         TP_NACIONALIDADE     0        TP_NACIONALIDADE     0.0
# 7          TP_ST_CONCLUSAO     0         TP_ST_CONCLUSAO     0.0
# 8          TP_ANO_CONCLUIU     0         TP_ANO_CONCLUIU     0.0
# 9                TP_ESCOLA     0               TP_ESCOLA     0.0
# 10               TP_ENSINO  9448               TP_ENSINO  3096.0
# 11            IN_TREINEIRO     0            IN_TREINEIRO     0.0
# 12  TP_DEPENDENCIA_ADM_ESC  9448  TP_DEPENDENCIA_ADM_ESC  3096.0
# ...

# %% [markdown]
# O conjunto de dados apresenta alguns atributos com valores nulos

# %% [markdown]
# ### Verificar a presença de outliers

# %%
dados.columns
# Out:
# Index(['NU_INSCRICAO', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NU_IDADE',
#        'TP_SEXO', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'TP_DEPENDENCIA_ADM_ESC', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DISLEXIA', 'IN_DISCALCULIA', 'IN_SABATISTA', 'IN_GESTANTE',
#        'IN_IDOSO', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT',
#        'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'TP_LINGUA',
#        'TP_STATUS_REDACAO', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3',
#        'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'Q001', 'Q002',
#        'Q006', 'Q024', 'Q025', 'Q026', 'Q027', 'Q047', 'NU_NOTA_MT'],
#       dtype='object')

# %%
# Selecionar todas as colunas exceto as: 
atributos_boxplot = ['CO_UF_RESIDENCIA', 'NU_IDADE',
       'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
       'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
       'TP_DEPENDENCIA_ADM_ESC', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
       'IN_DISLEXIA', 'IN_DISCALCULIA', 'IN_SABATISTA', 'IN_GESTANTE',
       'IN_IDOSO', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'TP_LINGUA',
       'TP_STATUS_REDACAO', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3',
       'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'NU_NOTA_MT']

for atributo in atributos_boxplot:
    plt.figure()
    sns.boxplot(dados[atributo], orient='vertical')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# ...

# %% [markdown]
# Podemos perceber que todas as colunas apresentam grande quantidade de outliers, nas próximas etapas será necessário aplicar técnicas para tratar esses outliers

# %% [markdown]
# ### Visualizar relação entre atributos

# %%
#sns.pairplot(dados, hue='NU_NOTA_MT')

# %% [markdown]
# ### Identificar correlações entre os atributos

# %%
correlacao = dados.corr()
correlacao.head()
# Out:
#                   CO_UF_RESIDENCIA  NU_IDADE  ...  NU_NOTA_REDACAO  NU_NOTA_MT
# CO_UF_RESIDENCIA          1.000000 -0.002017  ...         0.060629    0.107493
# NU_IDADE                 -0.002017  1.000000  ...        -0.116125   -0.061485
# TP_COR_RACA              -0.234786  0.009675  ...        -0.107840   -0.157364
# TP_NACIONALIDADE          0.009433 -0.017713  ...        -0.032759   -0.034965
# TP_ST_CONCLUSAO           0.025822 -0.253403  ...        -0.120580   -0.087869
#
# [5 rows x 33 columns]

# %%
correlacao['NU_NOTA_MT'].sort_values()
# Out:
# TP_LINGUA                -0.201726
# TP_COR_RACA              -0.157364
# TP_ST_CONCLUSAO          -0.087869
# TP_ENSINO                -0.086353
# NU_IDADE                 -0.061485
# TP_STATUS_REDACAO        -0.059376
# TP_NACIONALIDADE         -0.034965
# IN_TREINEIRO             -0.022287
# IN_SABATISTA             -0.016459
# IN_SURDEZ                -0.015249
# IN_IDOSO                 -0.011336
# IN_GESTANTE              -0.000945
# IN_BAIXA_VISAO            0.000685
# IN_DISLEXIA               0.001453
# TP_PRESENCA_CN            0.003552
# TP_PRESENCA_CH            0.003552
# IN_DISCALCULIA            0.009813
# TP_ANO_CONCLUIU           0.029039
# TP_ESCOLA                 0.069304
# CO_UF_RESIDENCIA          0.107493
# NU_NOTA_COMP1             0.299402
# NU_NOTA_COMP2             0.335638
# NU_NOTA_COMP4             0.342282
# NU_NOTA_COMP5             0.343337
# NU_NOTA_COMP3             0.350307
# TP_DEPENDENCIA_ADM_ESC    0.373233
# NU_NOTA_REDACAO           0.379376
# ...

# %%
# Atributos com maior correlação
correlacao[(correlacao['NU_NOTA_MT'] >= 0.2) | (correlacao['NU_NOTA_MT'] <= -0.2)].index
# Out:
# Index(['TP_DEPENDENCIA_ADM_ESC', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'TP_LINGUA', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3',
#        'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'NU_NOTA_MT'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(correlacao, annot=True)

# %% [markdown]
# ****
# # Próxima etapa: "Data Preparation"
#
# Tratamentos para serem realizados:
#
#
# 1.   Nos dados de treino, remover os atributos que não estão presentes nos dados de teste
# 1.   Remover atributos que contém valores nulos: TP_ENSINO, TP_DEPENDENCIA_ADM_ESC, NU_NOTA_CN, NU_NOTA_CH, NU_NOTA_LC, TP_STATUS_REDACAO, NU_NOTA_COMP1, NU_NOTA_COMP2, NU_NOTA_COMP3, NU_NOTA_COMP4, NU_NOTA_COMP5, NU_NOTA_REDACAO, Q027
# 2.   Remover atributos que são textuais, futuramente esses atributos podem ser tratados para compor os dados de treino: SG_UF_RESIDENCIA, CO_PROVA_CN, CO_PROVA_CH, CO_PROVA_LC
# 3.   Converter valores do atributo 'CO_PROVA_MT' para letras ou números
# 3.   Binarizar atributos: TP_SEXO, CO_PROVA_MT, 'Q001', 'Q002',
#        'Q006', 'Q024', 'Q025', 'Q026', 'Q047'
# 4.   Nos dados de treino, remover linhas que tem valores nulos no atributo 'NU_NOTA_MT'
